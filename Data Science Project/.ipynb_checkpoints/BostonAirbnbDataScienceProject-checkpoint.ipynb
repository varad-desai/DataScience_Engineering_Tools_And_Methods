# %% [markdown]
# # Boston AirBnb Data

# %%
# Python Imports

import pandas as pd
import numpy as np
from collections import Counter

# %%
# Cleaning the listings data

# Loading data from csv files
listings_dataframe = pd.read_csv('listings.csv')

# replacing NaN values with 0
listings_dataframe.fillna(0, inplace=True)

# Extracting prices from the table
price = listings_dataframe['price']
prices=[]

# converting prices into a float value
for p in price:
    p=float(p[1:].replace(',',''))
    prices.append(p)

# replace the price column with the new column
listings_dataframe['price']=prices

# exclude the listings with 0 for price,beds,bedrooms,accomodates etc
listings_dataframe = listings_dataframe[listings_dataframe.bathrooms >0]
listings_dataframe = listings_dataframe[listings_dataframe.bedrooms > 0]
listings_dataframe = listings_dataframe[listings_dataframe.beds > 0]
listings_dataframe = listings_dataframe[listings_dataframe.price  > 0]
listings_dataframe = listings_dataframe[listings_dataframe.review_scores_rating  > 0]
listings_dataframe = listings_dataframe[listings_dataframe.reviews_per_month > 0]
listings_dataframe = listings_dataframe[listings_dataframe.accommodates  > 0]
listings_dataframe.head()
# Out:
#          id                            listing_url       scrape_id  \
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# 5  12386020  https://www.airbnb.com/rooms/12386020  20160906204935
#
#   last_scraped                                           name  \
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
# 5   2016-09-07                 Private Bedroom + Great Coffee
#
#                                              summary  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# ...

# %%
listings_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2506 entries, 1 to 3583
# Data columns (total 95 columns):
# id                                  2506 non-null int64
# listing_url                         2506 non-null object
# scrape_id                           2506 non-null int64
# last_scraped                        2506 non-null object
# name                                2506 non-null object
# summary                             2506 non-null object
# space                               2506 non-null object
# description                         2506 non-null object
# experiences_offered                 2506 non-null object
# neighborhood_overview               2506 non-null object
# notes                               2506 non-null object
# transit                             2506 non-null object
# access                              2506 non-null object
# interaction                         2506 non-null object
# house_rules                         2506 non-null object
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn import linear_model

# %%
# Defining Independent variables and Dependent Variables
X = pd.DataFrame(
    np.c_[listings_dataframe['host_response_time'], listings_dataframe['host_response_rate'], listings_dataframe['host_acceptance_rate'], listings_dataframe['host_is_superhost'], listings_dataframe['host_total_listings_count'], listings_dataframe['host_identity_verified'], listings_dataframe['latitude'], listings_dataframe['longitude'], listings_dataframe['property_type'], listings_dataframe['room_type'], listings_dataframe['accommodates'], listings_dataframe['bathrooms'], listings_dataframe['bedrooms'], listings_dataframe['beds'], listings_dataframe['bed_type'], listings_dataframe['guests_included'], listings_dataframe['minimum_nights'], listings_dataframe['availability_365'], listings_dataframe['number_of_reviews'], listings_dataframe['review_scores_rating'], listings_dataframe['review_scores_accuracy'], listings_dataframe['review_scores_cleanliness'], listings_dataframe['review_scores_checkin'], listings_dataframe['review_scores_communication'], listings_dataframe['review_scores_location'], listings_dataframe['review_scores_value'], listings_dataframe['instant_bookable'], listings_dataframe['cancellation_policy'], listings_dataframe['reviews_per_month']],     
    columns = ['host_response_time','host_response_rate','host_acceptance_rate','host_is_superhost','host_total_listings_count','host_identity_verified','latitude','longitude','property_type','room_type','accommodates','bathrooms','bedrooms','beds','bed_type','guests_included','minimum_nights','availability_365','number_of_reviews','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','instant_bookable','cancellation_policy','reviews_per_month']
)

Y = target["prices"]

# %%
# Splitting the data into training and testing dataset
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=9)

# %%
# Fitting the model using training data set
linear_regression_model = LinearRegression()
linear_regression_model.fit(X_train, Y_train)

# %%
# Predicting prices for test data set
predictions = linear_regression_model.predict(X_test)

# %%
# Checking the accuracy of the prediction using RootMeanSquare and R2 method
test_set_rmse = (np.sqrt(mean_squared_error(Y_test, predictions)))

test_set_r2 = r2_score(Y_test, predictions)

# %%
# Printing out the accuracy metrics
print("Accuracy Metric using Root Mean Square Method", + test_set_rmse)
print("Accuracy Metric using R2 Method", + test_set_r2)

# %% [markdown]
# For Root mean square method the lower the value is, the better is the fit
# And for R2 method, the closer the value is towards 1, the better the fit is
